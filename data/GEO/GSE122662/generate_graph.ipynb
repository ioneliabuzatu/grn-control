# %%
import os
import pandas as pd

# %%
path_count_matrix = "./final-graph/107G_D0_ipsc_norm.csv"

# %%
df = pd.read_csv(path_count_matrix)
df
# Out:
#          Acta2       Mt2     Tagln      Myl9      Cnn2    Dppa5a       Mt1  \
# 0     0.943884 -0.385831  1.161857  0.919042  1.190023 -0.789237 -0.574175
# 1     0.910473 -0.870818  0.782461  0.807008  0.584674 -0.789237 -0.372157
# 2     0.613475 -0.870818  1.234733  1.535812  1.326174 -0.789237 -0.351049
# 3     0.853486 -0.870818  0.883682  0.278090  0.698634 -0.789237 -1.056607
# 4     0.922775 -0.870818  0.759750  0.750706  0.636831 -0.789237 -0.123318
# ...        ...       ...       ...       ...       ...       ...       ...
# 7153 -1.182305  0.746184 -1.155123 -1.119918 -1.196978  1.332741  1.080850
# 7154 -1.182305  0.151039 -1.155123 -1.119918 -1.196978  1.789483  0.843137
# 7155  0.025855  0.566473  0.655548 -0.139527 -0.460073 -0.215042  0.373115
# 7156 -1.182305  1.359336 -1.155123 -1.119918 -1.196978  1.217997  1.073120
# 7157 -1.182305  1.163327 -1.155123 -1.119918 -1.196978  1.245069  1.387488
#
# ...

# %%
EXP_MTX_QC_FNAME = os.path.join('/home/ionelia/pycharm-projects/grn-control/data/GEO/GSE122662', path_count_matrix)
TFS_FNAME = os.path.join('/home/ionelia/pycharm-projects/grn-control/data', 'mouse_riken_tfs.txt')
ADJACENCIES_FNAME = os.path.join('/home/ionelia/pycharm-projects/grn-control/data/GEO/GSE122662', 'final-graph/107G_genes_graph_adjacencies_norm.tsv')

# %%
# !pyscenic grn {EXP_MTX_QC_FNAME} {TFS_FNAME} -o {ADJACENCIES_FNAME} --num_workers 20
# Out:
# 2022-05-28 16:38:04,388 - pyscenic.cli.pyscenic - INFO - Loading expression matrix.
#
# 2022-05-28 16:38:04,447 - pyscenic.cli.pyscenic - INFO - Inferring regulatory networks.
# preparing dask client
# parsing input
# creating dask graph
# 20 partitions
# computing dask graph
# not shutting down client, client was created externally
# finished
#
# 2022-05-28 16:38:15,027 - pyscenic.cli.pyscenic - INFO - Writing results to file.

# %% [markdown]
# ## Do it for the de-noised data
