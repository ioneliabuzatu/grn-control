# %%
import os
import pandas as pd

# %%
df = pd.read_csv("15000G_D0_ipsc.csv")
df
# Out:
#          Sox17    Mrpl15    Lypla1     Tcea1     Rgs20    Rb1cc1  \
# 0    -0.044752  0.472204 -0.769427  2.793780 -0.048385  1.405435
# 1    -0.044752 -1.250195 -0.769427 -0.563763 -0.048385 -0.499128
# 2    -0.044752 -1.250195 -0.769427 -0.563763 -0.048385 -0.499128
# 3    -0.044752 -1.250195 -0.769427 -0.563763 -0.048385  2.993704
# 4    -0.044752 -1.250195 -0.769427 -0.563763 -0.048385  1.011442
# ...        ...       ...       ...       ...       ...       ...
# 7153 -0.044752  0.022900  1.173836 -0.563763 -0.048385 -0.499128
# 7154 -0.044752 -0.042714  1.073683 -0.563763 -0.048385 -0.499128
# 7155 -0.044752  0.911839 -0.769427 -0.563763 -0.048385 -0.499128
# 7156 -0.044752  0.202599 -0.769427 -0.563763 -0.048385 -0.499128
# 7157 -0.044752 -0.238680 -0.769427  1.408024 -0.048385 -0.499128
#
#       4732440D04Rik   Fam150a    Pcmtd1   Gm26901  ...    mt-Nd6   mt-Cytb  \
# 0         -0.138357  2.851943 -0.275218 -0.072922  ... -0.156907 -0.888972
# ...

# %%
EXP_MTX_QC_FNAME = os.path.join('/home/ionelia/pycharm-projects/grn-control/data/GEO/GSE122662', '15000G_D0_ipsc.csv')
HUMAN_TFS_FNAME = os.path.join('/home/ionelia/pycharm-projects/grn-control/data', 'mouse_riken_tfs.txt')
ADJACENCIES_FNAME = os.path.join('/home/ionelia/pycharm-projects/grn-control/data/GEO/GSE122662', 'graph_adjacencies.tsv')

# %%
# !pyscenic grn {EXP_MTX_QC_FNAME} {HUMAN_TFS_FNAME} -o {ADJACENCIES_FNAME} --num_workers 20
# Out:
# 2022-04-18 20:55:01,703 - pyscenic.cli.pyscenic - INFO - Loading expression matrix.
#
# 2022-04-18 20:55:20,982 - pyscenic.cli.pyscenic - INFO - Inferring regulatory networks.
# preparing dask client
# parsing input
# creating dask graph
# 20 partitions
# computing dask graph
# distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 15% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 16% CPU time recently (threshold: 10%)
# ...
